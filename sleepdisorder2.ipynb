# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sleep_disorder_data.csv')

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df['Sleep Disorder'].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df = df.drop('Person ID',axis=1)

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df['Blood Pressure'] = df['Blood Pressure'].str.split('/')

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df['Blood Pressure'][0]
# Out:
# ['126', '83']

# %%
a = []
b = []
for i in df['Blood Pressure']:
    a.append(i[0])
    b.append(i[1])

# %%
df['Systolic_BP'] = a

# %%
df['Diastolic_BP'] = b

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df = df.drop('Blood Pressure',axis=1)

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# ...

# %%
sd = df.pop('Sleep Disorder')

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# ...

# %%
df['Sleep Disorder'] = sd

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# ...

# %%
df['Sleep Disorder'].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df = df.dropna(subset=['Sleep Disorder'])

# %%
df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# 5      Male   28     Software Engineer             5.9                 4
# 6      Male   29               Teacher             6.3                 6
# 16   Female   29                 Nurse             6.5                 5
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category  Heart Rate  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
col = ['Gender','Occupation','BMI Category','Sleep Disorder']
for i in col:
    df[i] = le.fit_transform(df[i])
# Out:
# C:\Users\Smart\AppData\Local\Temp\ipykernel_5256\3049987088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = le.fit_transform(df[i])
# C:\Users\Smart\AppData\Local\Temp\ipykernel_5256\3049987088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = le.fit_transform(df[i])
# C:\Users\Smart\AppData\Local\Temp\ipykernel_5256\3049987088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 3         1   28           5             5.9                 4
# 4         1   28           5             5.9                 4
# 5         1   28           8             5.9                 4
# 6         1   29           9             6.3                 6
# 16        0   29           4             6.5                 5
# ..      ...  ...         ...             ...               ...
# 369       0   59           4             8.1                 9
# 370       0   59           4             8.0                 9
# 371       0   59           4             8.1                 9
# 372       0   59           4             8.1                 9
# 373       0   59           4             8.1                 9
#
#      Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# 3                         30             8             2          85
# ...

# %%
sns.scatterplot(data=df,x=df['Systolic_BP'],y=df['Diastolic_BP'],hue='Sleep Disorder')
plt.title('Systolic_BP vs Diastolic_BP by Sleep Disorder')
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# # To see if sleep disorders are associated with getting more or less sleep.

# %%
sns.boxplot(data=df, x='Sleep Disorder', y='Sleep Duration')
plt.title('Sleep Duration vs Sleep Disorder')
plt.show()

# %% [markdown]
# # 📈 Insight:
# # Insomniacs tend to sleep less and more consistently short hours.
# # Sleep apnea patients have more variable sleep duration — some sleep little, others long (possibly compensating), but quality may be low.

# %%
sns.boxplot(data=df, x='Sleep Disorder', y='Stress Level')
plt.title('Stress Level vs Sleep Disorder')
plt.show()

# %%
df.groupby('Sleep Disorder')['Stress Level'].median()
# Out:
# Sleep Disorder
# 0    7.0
# 1    7.0
# Name: Stress Level, dtype: float64

# %% [markdown]
# # 📈 Insight:
# # Stress is more consistent (less variable) in insomnia, but more scattered and extreme in sleep apnea.
# # Both disorders are linked to high stress, but sleep apnea shows a stronger and more unpredictable association.

# %%
sns.scatterplot(data=df, x='Sleep Duration', y='Heart Rate', hue='Sleep Disorder')
plt.title('Heart Rate vs Sleep Duration by Sleep Disorder')
plt.show()

# %%
sns.countplot(data=df, x='Occupation', hue='Sleep Disorder')
plt.title('Sleep Disorders Across Occupations')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sns.countplot(data=df, x='Occupation', hue='Sleep Disorder')
#       2 plt.title('Sleep Disorders Across Occupations')
#       3 plt.xticks(rotation=45)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
pd.crosstab(df['BMI Category'], df['Sleep Disorder']).plot(kind='bar', stacked=True)
plt.title('Sleep Disorder by BMI Category')
plt.ylabel('Count')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df, vars=['Sleep Duration', 'Stress Level', 'Heart Rate', 'Daily Steps'], hue='Sleep Disorder')
plt.suptitle('Pair Plot of Features by Sleep Disorder', y=1.02)
plt.show()
# Out:
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.histplot(data=df, x='Age', hue='Sleep Disorder', kde=True, multiple='stack')
plt.title('Age Distribution by Sleep Disorder')
plt.show()
# Out:
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(data=df, x='BMI Category', y='Physical Activity Level', hue='Sleep Disorder')
plt.title('BMI vs Physical Activity Level by Sleep Disorder')
plt.show()

# %%
df[['Systolic_BP', 'Diastolic_BP', 'Heart Rate', 'BMI Category', 'Stress Level']].corr()
# Out:
#               Systolic_BP  Diastolic_BP  Heart Rate  BMI Category  \
# Systolic_BP      1.000000      0.971213    0.104484      0.481130
# Diastolic_BP     0.971213      1.000000   -0.022726      0.486638
# Heart Rate       0.104484     -0.022726    1.000000     -0.123748
# BMI Category     0.481130      0.486638   -0.123748      1.000000
# Stress Level    -0.184056     -0.214422    0.598860      0.036478
#
#               Stress Level
# Systolic_BP      -0.184056
# Diastolic_BP     -0.214422
# Heart Rate        0.598860
# BMI Category      0.036478
# Stress Level      1.000000

# %%
sns.boxplot(data=df, x='Sleep Disorder', y='Systolic_BP')
plt.title('Systolic BP vs Sleep Disorder')
plt.show()

# %%
sns.boxplot(data=df, x='Sleep Disorder', y='Diastolic_BP')
plt.title('Diastolic BP vs Sleep Disorder')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(data=df, x='Occupation', y='Stress Level', hue='Sleep Disorder', split=True)
plt.xticks(rotation=45)
plt.title("Stress Level by Occupation and Sleep Disorder")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(data=df, x='BMI Category', y='Physical Activity Level', hue='Sleep Disorder')
plt.title("Physical Activity Level across BMI Categories by Disorder")
plt.show()
# Out:
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 36.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 45.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxenplot(data=df, x='Sleep Disorder', y='Daily Steps')
plt.title("Daily Steps Distribution by Sleep Disorder")
plt.show()
# Out:
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Smart\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
pd.crosstab([df['Gender'], df['Sleep Disorder']], df['BMI Category']).plot(kind='bar', stacked=True)
plt.title("BMI Category by Gender and Sleep Disorder")
plt.ylabel("Count")
plt.show()
